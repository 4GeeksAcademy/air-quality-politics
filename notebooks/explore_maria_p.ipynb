# %%
import pandas as pd

# %%
df=pd.read_csv('/workspaces/air-quality-politics/data/raw/resultado_final_con_ica_estaciones.csv', sep=';')

# %%
df.head()
# Out:
#    codigo_provincia nombre_provincia   año     sexo   edad  poblacion  \
# 0                 1      ARABA ALAVA  2013  hombres    0-4       1286
# 1                 1      ARABA ALAVA  2013  hombres  15-24       2024
# 2                 1      ARABA ALAVA  2013  hombres  25-34       4296
# 3                 1      ARABA ALAVA  2013  hombres  35-44       4050
# 4                 1      ARABA ALAVA  2013  hombres  45-54       1642
#
#    tasa_def_tot_1000hab  muertes_totales  muertes_respiratorias  \
# 0                  2.12                3                      0
# 1                  0.35                1                      0
# 2                  0.82                4                      0
# 3                  0.82                3                      6
# 4                  3.19                5                     39
#
#    proporcion_muerte_respiratoria  tasa_muerte_respiratoria_1000hab  \
# 0                             0.0                             0.000
# ...

# %%
df.shape
# Out:
# (9360, 19)

# %%
df.describe()
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#        codigo_provincia          año     poblacion  tasa_def_tot_1000hab  \
# count       9360.000000  9360.000000   9360.000000           9360.000000
# mean          26.500000  2017.500000   3302.436645             17.812645
# std           15.009133     2.872435   2716.600673             42.533044
# min            1.000000  2013.000000     19.000000              0.000000
# 25%           13.750000  2015.000000    992.750000              0.290000
# 50%           26.500000  2017.500000   2677.000000              1.290000
# 75%           39.250000  2020.000000   5111.500000              7.380000
# max           52.000000  2022.000000  14732.000000            208.850000
#
#        muertes_totales  muertes_respiratorias  proporcion_muerte_respiratoria  \
# ...

# %%
df=pd.read_csv('/workspaces/air-quality-politics/data/raw/resultado_final_todo_con_gobierno_y_edades.csv', sep=';')

# %%
df.describe()
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#        codigo_provincia_x          año     poblacion  tasa_def_tot_1000hab  \
# count         9360.000000  9360.000000   9360.000000           9360.000000
# mean            26.500000  2017.500000   3302.436645             17.812645
# std             15.009133     2.872435   2716.600673             42.533044
# min              1.000000  2013.000000     19.000000              0.000000
# 25%             13.750000  2015.000000    992.750000              0.290000
# 50%             26.500000  2017.500000   2677.000000              1.290000
# 75%             39.250000  2020.000000   5111.500000              7.380000
# max             52.000000  2022.000000  14732.000000            208.850000
#
#        muertes_totales  muertes_respiratorias  proporcion_muerte_respiratoria  \
# ...
